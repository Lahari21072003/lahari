# %% [markdown]
# <a href="https://colab.research.google.com/github/Lahari21072003/lahari/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***DATA MANIPULATION AND ANALYSIS USING PANDAS***

# %% [markdown]
# In Machine learning we need dataset to operate the algorithm, and dataset may be of training and testing data.
#
# When we are looking for dataset from various platforms and regions, we will be getting the dataset that consists of NAN, NULL and various other forms.
#
# So it is important to modify and clean the data for better insights.
#
# PANDAS is a famous library of python which helps us in giving out the accurate insights of the data.

# %% [markdown]
# ** Before moving forward, ensure that Pandas is installed in your system**

# %%
#Use this to install pandas

# %%
#Importing of pandas library
import pandas as pd

# %% [markdown]
# Basic operations using pandas

# %%
#Creating a new DataFrame

import pandas as pd

df1 = pd.DataFrame({
    'A': [10, 20, 30, 40],
    'B': ['apple', 'banana', 'cherry', 'date']
})

print(df1)
# Out:
#     A       B
# 0  10   apple
# 1  20  banana
# 2  30  cherry
# 3  40    date

# %%
df1
# Out:
#     A       B
# 0  10   apple
# 1  20  banana
# 2  30  cherry
# 3  40    date

# %% [markdown]
# Data Frame is being created, where [ A,B ] are the names of columns

# %%
df1.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %% [markdown]
# *** Loading of the data ***

# %%
df = pd.read_csv("/titanic.csv")

# %% [markdown]
# *** Data Exploration ***

# %%
data = {
    'match_id': [1, 2, 3, 4, 5],
    'season': [2020, 2020, 2020, 2020, 2020],
    'team1': ['MI', 'CSK', 'RCB', 'KKR', 'SRH'],
    'team2': ['DC', 'RR', 'KXIP', 'SRH', 'RCB'],
    'winner': ['MI', 'CSK', 'RCB', 'KKR', 'RCB'],
    'venue': ['Mumbai', 'Chennai', 'Bangalore', 'Kolkata', 'Hyderabad'],
    'player_of_match': ['Rohit Sharma', 'MS Dhoni', 'Virat Kohli', 'Andre Russell', 'AB de Villiers']
}

df = pd.DataFrame(data)

# %%
df.tail()

#View bottom rows
# Out:
#    match_id  season team1 team2 winner      venue player_of_match
# 0         1    2020    MI    DC     MI     Mumbai    Rohit Sharma
# 1         2    2020   CSK    RR    CSK    Chennai        MS Dhoni
# 2         3    2020   RCB  KXIP    RCB  Bangalore     Virat Kohli
# 3         4    2020   KKR   SRH    KKR    Kolkata   Andre Russell
# 4         5    2020   SRH   RCB    RCB  Hyderabad  AB de Villiers

# %%
import pandas as pd

# Sample COVID-19 dataset
data = {
    'date': pd.date_range(start='2020-01-01', periods=10, freq='D'),
    'country': ['USA', 'India', 'Brazil', 'Russia', 'UK', 'France', 'Italy', 'Germany', 'Spain', 'China'],
    'confirmed_cases': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
    'deaths': [5, 8, 12, 15, 20, 25, 30, 35, 40, 50],
    'recoveries': [50, 120, 200, 300, 400, 500, 600, 700, 800, 900]
}

df = pd.DataFrame(data)
print(df.head(10))
# Out:
#         date  country  confirmed_cases  deaths  recoveries
# 0 2020-01-01      USA              100       5          50
# 1 2020-01-02    India              200       8         120
# 2 2020-01-03   Brazil              300      12         200
# 3 2020-01-04   Russia              400      15         300
# 4 2020-01-05       UK              500      20         400
# 5 2020-01-06   France              600      25         500
# 6 2020-01-07    Italy              700      30         600
# 7 2020-01-08  Germany              800      35         700
# 8 2020-01-09    Spain              900      40         800
# 9 2020-01-10    China             1000      50         900

# %%
df.describe()

#Statistics Summary
# Out:
#                       date  confirmed_cases     deaths  recoveries
# count                   10        10.000000  10.000000   10.000000
# mean   2020-01-05 12:00:00       550.000000  24.000000  457.000000
# min    2020-01-01 00:00:00       100.000000   5.000000   50.000000
# 25%    2020-01-03 06:00:00       325.000000  12.750000  225.000000
# 50%    2020-01-05 12:00:00       550.000000  22.500000  450.000000
# 75%    2020-01-07 18:00:00       775.000000  33.750000  675.000000
# max    2020-01-10 00:00:00      1000.000000  50.000000  900.000000
# std                    NaN       302.765035  14.712051  292.196661

# %%
df.dtypes

#Kind of data present in each column
# Out:
# date               datetime64[ns]
# country                    object
# confirmed_cases             int64
# deaths                      int64
# recoveries                  int64
# dtype: object

# %%
df.isnull().sum()

#Finding out the missing values count in each and every column
# Out:
# date               0
# country            0
# confirmed_cases    0
# deaths             0
# recoveries         0
# dtype: int64

# %%
df['deaths']

#select a particular column --->>> df["name_of_column"]
# Out:
# 0     5
# 1     8
# 2    12
# 3    15
# 4    20
# 5    25
# 6    30
# 7    35
# 8    40
# 9    50
# Name: deaths, dtype: int64

# %%
df[['confirmed_cases','recoveries']]

#Select multiple columns --->>> df[["column_1","column_2"]]
# Out:
#    confirmed_cases  recoveries
# 0              100          50
# 1              200         120
# 2              300         200
# 3              400         300
# 4              500         400
# 5              600         500
# 6              700         600
# 7              800         700
# 8              900         800
# 9             1000         900

# %%
v = df[['confirmed_cases','deaths','recoveries']]

# %%
v
# Out:
#       Age  Survived            Ticket
# 0    22.0         0         A/5 21171
# 1    38.0         1          PC 17599
# 2    26.0         1  STON/O2. 3101282
# 3    35.0         1            113803
# 4    35.0         0            373450
# ..    ...       ...               ...
# 886  27.0         0            211536
# 887  19.0         1            112053
# 888   NaN         0        W./C. 6607
# 889  26.0         1            111369
# 890  32.0         0            370376
#
# [891 rows x 3 columns]

# %%
type(v)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df.iloc[1:100:3])
# Out:
#         date  country  confirmed_cases  deaths  recoveries
# 1 2020-01-02    India              200       8         120
# 4 2020-01-05       UK              500      20         400
# 7 2020-01-08  Germany              800      35         700

# %%
print(df[['confirmed_cases', 'deaths']][1:50:4])
# Out:
#    confirmed_cases  deaths
# 1              200       8
# 5              600      25
# 9             1000      50

# %%
df.columns

#view of all the columns present in the dataset
# Out:
# Index(['date', 'country', 'confirmed_cases', 'deaths', 'recoveries'], dtype='object')

# %%
df.iloc[1:5]

#Here we are selecting rows with the help of indexing

# iloc [1:5] ---->> Start from index 1 and go till index 4 (exclude last index from condition same like of indexing in any coding language)
# Out:
#         date country  confirmed_cases  deaths  recoveries
# 1 2020-01-02   India              200       8         120
# 2 2020-01-03  Brazil              300      12         200
# 3 2020-01-04  Russia              400      15         300
# 4 2020-01-05      UK              500      20         400

# %%
df.iloc[0:5]

#start from 0th index and go till 4th index
# Out:
#         date country  confirmed_cases  deaths  recoveries
# 0 2020-01-01     USA              100       5          50
# 1 2020-01-02   India              200       8         120
# 2 2020-01-03  Brazil              300      12         200
# 3 2020-01-04  Russia              400      15         300
# 4 2020-01-05      UK              500      20         400

# %%
print(df['confirmed_cases'] > 1050)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: confirmed_cases, dtype: bool

# %%
filtered_df = df[df['confirmed_cases'] > 1050]

# %%
#Adding of new column :

df['Active_Cases'] = df['confirmed_cases'] - (df['deaths'] + df['recoveries'])

# %%
print(df.head())
# Out:
#         date country  confirmed_cases  deaths  recoveries  Active_Cases
# 0 2020-01-01     USA              100       5          50            45
# 1 2020-01-02   India              200       8         120            72
# 2 2020-01-03  Brazil              300      12         200            88
# 3 2020-01-04  Russia              400      15         300            85
# 4 2020-01-05      UK              500      20         400            80

# %%
df['new_col'] = df['Age'] + 10

# %%
df
# Out:
#         date  country  confirmed_cases  deaths  recoveries  Active_Cases
# 0 2020-01-01      USA              100       5          50            45
# 1 2020-01-02    India              200       8         120            72
# 2 2020-01-03   Brazil              300      12         200            88
# 3 2020-01-04   Russia              400      15         300            85
# 4 2020-01-05       UK              500      20         400            80
# 5 2020-01-06   France              600      25         500            75
# 6 2020-01-07    Italy              700      30         600            70
# 7 2020-01-08  Germany              800      35         700            65
# 8 2020-01-09    Spain              900      40         800            60
# 9 2020-01-10    China             1000      50         900            50

# %%
df
# Out:
#         date  country  confirmed_cases  deaths  recoveries  Active_Cases
# 0 2020-01-01      USA              100       5          50            45
# 1 2020-01-02    India              200       8         120            72
# 2 2020-01-03   Brazil              300      12         200            88
# 3 2020-01-04   Russia              400      15         300            85
# 4 2020-01-05       UK              500      20         400            80
# 5 2020-01-06   France              600      25         500            75
# 6 2020-01-07    Italy              700      30         600            70
# 7 2020-01-08  Germany              800      35         700            65
# 8 2020-01-09    Spain              900      40         800            60
# 9 2020-01-10    China             1000      50         900            50

# %%
df.dtypes
# Out:
# date               datetime64[ns]
# country                    object
# confirmed_cases             int64
# deaths                      int64
# recoveries                  int64
# Active_Cases                int64
# dtype: object

# %%
df['Active_Cases'] = df['confirmed_cases'] - (df['deaths'] + df['recoveries'])
df['Fatality_Rate'] = (df['deaths'] / df['confirmed_cases']) * 100

# %%
df
# Out:
#         date  country  confirmed_cases  deaths  recoveries  Active_Cases  \
# 0 2020-01-01      USA              100       5          50            45
# 1 2020-01-02    India              200       8         120            72
# 2 2020-01-03   Brazil              300      12         200            88
# 3 2020-01-04   Russia              400      15         300            85
# 4 2020-01-05       UK              500      20         400            80
# 5 2020-01-06   France              600      25         500            75
# 6 2020-01-07    Italy              700      30         600            70
# 7 2020-01-08  Germany              800      35         700            65
# 8 2020-01-09    Spain              900      40         800            60
# 9 2020-01-10    China             1000      50         900            50
#
#    Fatality_Rate
# 0       5.000000
# 1       4.000000
# 2       4.000000
# 3       3.750000
# 4       4.000000
# 5       4.166667
# 6       4.285714
# 7       4.375000
# 8       4.444444
# 9       5.000000

# %%
df.columns
# Out:
# Index(['date', 'country', 'confirmed_cases', 'deaths', 'recoveries',
#        'Active_Cases', 'Fatality_Rate'],
#       dtype='object')

# %%
df.shape
# Out:
# (10, 7)

# %%
df
# Out:
#         date  country  confirmed_cases  deaths  recoveries  Active_Cases  \
# 0 2020-01-01      USA              100       5          50            45
# 1 2020-01-02    India              200       8         120            72
# 2 2020-01-03   Brazil              300      12         200            88
# 3 2020-01-04   Russia              400      15         300            85
# 4 2020-01-05       UK              500      20         400            80
# 5 2020-01-06   France              600      25         500            75
# 6 2020-01-07    Italy              700      30         600            70
# 7 2020-01-08  Germany              800      35         700            65
# 8 2020-01-09    Spain              900      40         800            60
# 9 2020-01-10    China             1000      50         900            50
#
#    Fatality_Rate
# 0       5.000000
# 1       4.000000
# 2       4.000000
# 3       3.750000
# 4       4.000000
# 5       4.166667
# 6       4.285714
# 7       4.375000
# 8       4.444444
# 9       5.000000

# %%
print(df['confirmed_cases'][0:4])
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# Name: confirmed_cases, dtype: int64
